# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
g1 = nx.erdos_renyi_graph(20,0.5)
nx.draw(g1)
plt.show()

# %%
l = []
for i in range(20):
    for neb in g1.neighbors(i):
        l = g1.degree(neb)
        #print (l)
    print (g1.degree(i), np.mean(l))
# Out:
# 5 13.0
# 14 10.0
# 12 11.0
# 8 6.0
# 6 9.0
# 13 10.0
# 10 10.0
# 10 9.0
# 5 10.0
# 11 9.0
# 7 9.0
# 6 9.0
# 12 10.0
# 9 9.0
# 10 9.0
# 9 10.0
# 8 12.0
# 12 10.0
# 11 9.0
# 10 9.0

# %%
g2 = nx.barabasi_albert_graph(20,1)
nx.draw(g2)
plt.show()

# %%
l = []
for i in range(20):
    for neb in g2.neighbors(i):
        l = g2.degree(neb)
        #print (l)
    print (g2.degree(i), np.mean(l))

# %%
g3=nx.watts_strogatz_graph(30,3,0.1)
nx.draw(g3)
plt.show()

# %%
l = []
for i in range(20):
    for neb in g3.neighbors(i):
        l = g3.degree(neb)
        #print (l)
    print (g3.degree(i), np.mean(l))
